# %% [markdown]
# <a href="https://colab.research.google.com/github/sba25005-code/python-playground/blob/main/Python_Play_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"hello world"
# Out:
# 'hello world'

# %%
123456789+987654321
# Out:
# 1111111110
